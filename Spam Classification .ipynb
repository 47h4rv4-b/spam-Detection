# %% [markdown]
# # Demo - Understanding data set

# %%
import pandas as pd
import numpy as np
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
data = pd.read_csv('https://techlearn-cdn.s3.amazonaws.com/project_GmailSpamClassification/spam.csv',encoding='cp1252')

# %%
data.head()
# Out:
#      v1  ... Unnamed: 4
# 0   ham  ...        NaN
# 1   ham  ...        NaN
# 2  spam  ...        NaN
# 3   ham  ...        NaN
# 4   ham  ...        NaN
#
# [5 rows x 5 columns]

# %%
data = data[['v1','v2']]

# %%
data.head()
# Out:
#    v1                                                 v2
# 0   0  Go until jurong point, crazy.. Available only ...
# 1   0                      Ok lar... Joking wif u oni...
# 2   1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   0  U dun say so early hor... U c already then say...
# 4   0  Nah I don't think he goes to usf, he lives aro...

# %%
data['v1'] = data['v1'].apply(lambda x:0 if x=='ham' else 1)

# %%
data
# Out:
#       v1                                                 v2
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...
# ...   ..                                                ...
# 5567   1  This is the 2nd time we have tried 2 contact u...
# 5568   0              Will Ì_ b going to esplanade fr home?
# 5569   0  Pity, * was in mood for that. So...any other s...
# 5570   0  The guy did some bitching but I acted like i'd...
# 5571   0                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %% [markdown]
# # - Text Pre-Processing

# %%
def process(x):
    temp = []
    document = nlp(x.lower())
    print(document)
    for i in document:
        if i.is_stop!=True and i.is_punct!= True:
            print(i)
            temp.append(i.lemma_)
            print(temp)
        else:
            pass
        
    return (' '.join(temp))

# %%
data['v2'] = data['v2'].apply(lambda x: process(x))
# Out:
# Streaming output truncated to the last 5000 lines.
# ['dunno']
# leh
# ['dunno', 'leh']
# nt
# ['dunno', 'leh', 'not']
# remember
# ['dunno', 'leh', 'not', 'remember']
# mayb
# ['dunno', 'leh', 'not', 'remember', 'mayb']
# lor
# ['dunno', 'leh', 'not', 'remember', 'mayb', 'lor']
# wat
# ['dunno', 'leh', 'not', 'remember', 'mayb', 'lor', 'wat']
# time
# ['dunno', 'leh', 'not', 'remember', 'mayb', 'lor', 'wat', 'time']
# r
# ['dunno', 'leh', 'not', 'remember', 'mayb', 'lor', 'wat', 'time', 'r']
# meeting
# ['dunno', 'leh', 'not', 'remember', 'mayb', 'lor', 'wat', 'time', 'r', 'meet']
# tmr
# ['dunno', 'leh', 'not', 'remember', 'mayb', 'lor', 'wat', 'time', 'r', 'meet', 'tmr']
# best msg: it's hard to be with a person, when u know that one more step foward will make u fall in love.. &amp; one step back can ruin ur friendship.. good night:-) ...
# best
# ['good']
# msg
# ['good', 'msg']
# hard
# ['good', 'msg', 'hard']
# person
# ['good', 'msg', 'hard', 'person']
# u
# ['good', 'msg', 'hard', 'person', 'u']
# know
# ['good', 'msg', 'hard', 'person', 'u', 'know']
# step
# ['good', 'msg', 'hard', 'person', 'u', 'know', 'step']
# foward
# ['good', 'msg', 'hard', 'person', 'u', 'know', 'step', 'foward']
# u
# ['good', 'msg', 'hard', 'person', 'u', 'know', 'step', 'foward', 'u']
# fall
# ['good', 'msg', 'hard', 'person', 'u', 'know', 'step', 'foward', 'u', 'fall']
# love
# ['good', 'msg', 'hard', 'person', 'u', 'know', 'step', 'foward', 'u', 'fall', 'love']
# amp
# ['good', 'msg', 'hard', 'person', 'u', 'know', 'step', 'foward', 'u', 'fall', 'love', 'amp']
# step
# ['good', 'msg', 'hard', 'person', 'u', 'know', 'step', 'foward', 'u', 'fall', 'love', 'amp', 'step']
# ruin
# ['good', 'msg', 'hard', 'person', 'u', 'know', 'step', 'foward', 'u', 'fall', 'love', 'amp', 'step', 'ruin']
# ur
# ['good', 'msg', 'hard', 'person', 'u', 'know', 'step', 'foward', 'u', 'fall', 'love', 'amp', 'step', 'ruin', 'ur']
# friendship
# ['good', 'msg', 'hard', 'person', 'u', 'know', 'step', 'foward', 'u', 'fall', 'love', 'amp', 'step', 'ruin', 'ur', 'friendship']
# good
# ['good', 'msg', 'hard', 'person', 'u', 'know', 'step', 'foward', 'u', 'fall', 'love', 'amp', 'step', 'ruin', 'ur', 'friendship', 'good']
# night:-
# ['good', 'msg', 'hard', 'person', 'u', 'know', 'step', 'foward', 'u', 'fall', 'love', 'amp', 'step', 'ruin', 'ur', 'friendship', 'good', 'night:-']
# urgent! your mobile number has been awarded with a å£2000 prize guaranteed. call 09061790126 from land line. claim 3030. valid 12hrs only 150ppm
# urgent
# ['urgent']
# mobile
# ['urgent', 'mobile']
# number
# ['urgent', 'mobile', 'number']
# awarded
# ['urgent', 'mobile', 'number', 'award']
# å£2000
# ['urgent', 'mobile', 'number', 'award', 'å£2000']
# prize
# ['urgent', 'mobile', 'number', 'award', 'å£2000', 'prize']
# guaranteed
# ['urgent', 'mobile', 'number', 'award', 'å£2000', 'prize', 'guarantee']
# 09061790126
# ['urgent', 'mobile', 'number', 'award', 'å£2000', 'prize', 'guarantee', '09061790126']
# land
# ['urgent', 'mobile', 'number', 'award', 'å£2000', 'prize', 'guarantee', '09061790126', 'land']
# line
# ['urgent', 'mobile', 'number', 'award', 'å£2000', 'prize', 'guarantee', '09061790126', 'land', 'line']
# claim
# ['urgent', 'mobile', 'number', 'award', 'å£2000', 'prize', 'guarantee', '09061790126', 'land', 'line', 'claim']
# 3030
# ['urgent', 'mobile', 'number', 'award', 'å£2000', 'prize', 'guarantee', '09061790126', 'land', 'line', 'claim', '3030']
# valid
# ['urgent', 'mobile', 'number', 'award', 'å£2000', 'prize', 'guarantee', '09061790126', 'land', 'line', 'claim', '3030', 'valid']
# 12hrs
# ['urgent', 'mobile', 'number', 'award', 'å£2000', 'prize', 'guarantee', '09061790126', 'land', 'line', 'claim', '3030', 'valid', '12hrs']
# 150ppm
# ['urgent', 'mobile', 'number', 'award', 'å£2000', 'prize', 'guarantee', '09061790126', 'land', 'line', 'claim', '3030', 'valid', '12hrs', '150ppm']
# helloooo... wake up..! \sweet\" \"morning\" \"welcomes\" \"you\" \"enjoy\" \"this day\" \"with full of joy\".. \"gud mrng\"."
# helloooo
# ['helloooo']
# wake
# ['helloooo', 'wake']
# \sweet\
# ['helloooo', 'wake', '\\sweet\\']
# \"morning\
# ['helloooo', 'wake', '\\sweet\\', '\\"morning\\']
# \"welcomes\
# ['helloooo', 'wake', '\\sweet\\', '\\"morning\\', '\\"welcomes\\']
# \"you\
# ['helloooo', 'wake', '\\sweet\\', '\\"morning\\', '\\"welcomes\\', '\\"you\\']
# \"enjoy\
# ['helloooo', 'wake', '\\sweet\\', '\\"morning\\', '\\"welcomes\\', '\\"you\\', '\\"enjoy\\']
# \"this
# ['helloooo', 'wake', '\\sweet\\', '\\"morning\\', '\\"welcomes\\', '\\"you\\', '\\"enjoy\\', '\\"this']
# day\
# ['helloooo', 'wake', '\\sweet\\', '\\"morning\\', '\\"welcomes\\', '\\"you\\', '\\"enjoy\\', '\\"this', 'day\\']
# \"with
# ['helloooo', 'wake', '\\sweet\\', '\\"morning\\', '\\"welcomes\\', '\\"you\\', '\\"enjoy\\', '\\"this', 'day\\', '\\"with']
# joy\
# ['helloooo', 'wake', '\\sweet\\', '\\"morning\\', '\\"welcomes\\', '\\"you\\', '\\"enjoy\\', '\\"this', 'day\\', '\\"with', 'joy\\']
# \"gud
# ['helloooo', 'wake', '\\sweet\\', '\\"morning\\', '\\"welcomes\\', '\\"you\\', '\\"enjoy\\', '\\"this', 'day\\', '\\"with', 'joy\\', '\\"gud']
# mrng\
# ['helloooo', 'wake', '\\sweet\\', '\\"morning\\', '\\"welcomes\\', '\\"you\\', '\\"enjoy\\', '\\"this', 'day\\', '\\"with', 'joy\\', '\\"gud', 'mrng\\']
# vikky, come around  &lt;time&gt; ..
# vikky
# ['vikky']
# come
# ['vikky', 'come']
#
# ['vikky', 'come', ' ']
# lt;time&gt
# ['vikky', 'come', ' ', 'lt;time&gt']
# and how you will do that, princess? :)
# princess
# ['princess']
# i have gone into get info bt dont know what to do
# gone
# ['go']
# info
# ['go', 'info']
# bt
# ['go', 'info', 'bt']
# nt
# ['go', 'info', 'bt', 'not']
# know
# ['go', 'info', 'bt', 'not', 'know']
# yeah, probably here for a while
# yeah
# ['yeah']
# probably
# ['yeah', 'probably']
# sent me ur email id soon
# sent
# ['send']
# ur
# ['send', 'ur']
# email
# ['send', 'ur', 'email']
# d
# ['send', 'ur', 'email', 'would']
# soon
# ['send', 'ur', 'email', 'would', 'soon']
# urgent! you have won a 1 week free membership in our å£100,000 prize jackpot! txt the word: claim to no: 81010 t&c www.dbuk.net lccltd pobox 4403ldnw1a7rw18
# urgent
# ['urgent']
# won
# ['urgent', 'win']
# 1
# ['urgent', 'win', '1']
# week
# ['urgent', 'win', '1', 'week']
# free
# ['urgent', 'win', '1', 'week', 'free']
# membership
# ['urgent', 'win', '1', 'week', 'free', 'membership']
# å£100,000
# ['urgent', 'win', '1', 'week', 'free', 'membership', 'å£100,000']
# prize
# ['urgent', 'win', '1', 'week', 'free', 'membership', 'å£100,000', 'prize']
# jackpot
# ['urgent', 'win', '1', 'week', 'free', 'membership', 'å£100,000', 'prize', 'jackpot']
# txt
# ['urgent', 'win', '1', 'week', 'free', 'membership', 'å£100,000', 'prize', 'jackpot', 'txt']
# word
# ['urgent', 'win', '1', 'week', 'free', 'membership', 'å£100,000', 'prize', 'jackpot', 'txt', 'word']
# claim
# ['urgent', 'win', '1', 'week', 'free', 'membership', 'å£100,000', 'prize', 'jackpot', 'txt', 'word', 'claim']
# 81010
# ['urgent', 'win', '1', 'week', 'free', 'membership', 'å£100,000', 'prize', 'jackpot', 'txt', 'word', 'claim', '81010']
# t&c
# ['urgent', 'win', '1', 'week', 'free', 'membership', 'å£100,000', 'prize', 'jackpot', 'txt', 'word', 'claim', '81010', 't&c']
# www.dbuk.net
# ['urgent', 'win', '1', 'week', 'free', 'membership', 'å£100,000', 'prize', 'jackpot', 'txt', 'word', 'claim', '81010', 't&c', 'www.dbuk.net']
# lccltd
# ['urgent', 'win', '1', 'week', 'free', 'membership', 'å£100,000', 'prize', 'jackpot', 'txt', 'word', 'claim', '81010', 't&c', 'www.dbuk.net', 'lccltd']
# pobox
# ['urgent', 'win', '1', 'week', 'free', 'membership', 'å£100,000', 'prize', 'jackpot', 'txt', 'word', 'claim', '81010', 't&c', 'www.dbuk.net', 'lccltd', 'pobox']
# 4403ldnw1a7rw18
# ['urgent', 'win', '1', 'week', 'free', 'membership', 'å£100,000', 'prize', 'jackpot', 'txt', 'word', 'claim', '81010', 't&c', 'www.dbuk.net', 'lccltd', 'pobox', '4403ldnw1a7rw18']
# i'm still pretty weak today .. bad day ?
# pretty
# ['pretty']
# weak
# ['pretty', 'weak']
# today
# ['pretty', 'weak', 'today']
# bad
# ['pretty', 'weak', 'today', 'bad']
# day
# ['pretty', 'weak', 'today', 'bad', 'day']
# hey ! don't forget ... you are mine ... for me ... my possession ... my property ... mmm ... *childish smile* ...
# hey
# ['hey']
# forget
# ['hey', 'forget']
# possession
# ['hey', 'forget', 'possession']
# property
# ['hey', 'forget', 'possession', 'property']
# mmm
# ['hey', 'forget', 'possession', 'property', 'mmm']
# childish
# ['hey', 'forget', 'possession', 'property', 'mmm', 'childish']
# smile
# ['hey', 'forget', 'possession', 'property', 'mmm', 'childish', 'smile']
# an excellent thought by a misundrstud frnd: i knw u hate me bt the day wen u'll knw the truth u'll hate urself:-( gn:-)
# excellent
# ['excellent']
# thought
# ['excellent', 'thought']
# misundrstud
# ['excellent', 'thought', 'misundrstud']
# frnd
# ['excellent', 'thought', 'misundrstud', 'frnd']
# knw
# ['excellent', 'thought', 'misundrstud', 'frnd', 'knw']
# u
# ['excellent', 'thought', 'misundrstud', 'frnd', 'knw', 'u']
# hate
# ['excellent', 'thought', 'misundrstud', 'frnd', 'knw', 'u', 'hate']
# bt
# ['excellent', 'thought', 'misundrstud', 'frnd', 'knw', 'u', 'hate', 'bt']
# day
# ['excellent', 'thought', 'misundrstud', 'frnd', 'knw', 'u', 'hate', 'bt', 'day']
# wen
# ['excellent', 'thought', 'misundrstud', 'frnd', 'knw', 'u', 'hate', 'bt', 'day', 'wen']
# u'll
# ['excellent', 'thought', 'misundrstud', 'frnd', 'knw', 'u', 'hate', 'bt', 'day', 'wen', "u'll"]
# knw
# ['excellent', 'thought', 'misundrstud', 'frnd', 'knw', 'u', 'hate', 'bt', 'day', 'wen', "u'll", 'knw']
# truth
# ['excellent', 'thought', 'misundrstud', 'frnd', 'knw', 'u', 'hate', 'bt', 'day', 'wen', "u'll", 'knw', 'truth']
# u'll
# ['excellent', 'thought', 'misundrstud', 'frnd', 'knw', 'u', 'hate', 'bt', 'day', 'wen', "u'll", 'knw', 'truth', "u'll"]
# hate
# ['excellent', 'thought', 'misundrstud', 'frnd', 'knw', 'u', 'hate', 'bt', 'day', 'wen', "u'll", 'knw', 'truth', "u'll", 'hate']
# urself:-
# ['excellent', 'thought', 'misundrstud', 'frnd', 'knw', 'u', 'hate', 'bt', 'day', 'wen', "u'll", 'knw', 'truth', "u'll", 'hate', 'urself:-']
# gn:-
# ['excellent', 'thought', 'misundrstud', 'frnd', 'knw', 'u', 'hate', 'bt', 'day', 'wen', "u'll", 'knw', 'truth', "u'll", 'hate', 'urself:-', 'gn:-']
# hey! congrats 2u2. id luv 2 but ive had 2 go home!
# hey
# ['hey']
# congrats
# ['hey', 'congrat']
# 2u2
# ['hey', 'congrat', '2u2']
# d
# ['hey', 'congrat', '2u2', 'would']
# luv
# ['hey', 'congrat', '2u2', 'would', 'luv']
# 2
# ['hey', 'congrat', '2u2', 'would', 'luv', '2']
# ve
# ['hey', 'congrat', '2u2', 'would', 'luv', '2', 'have']
# 2
# ['hey', 'congrat', '2u2', 'would', 'luv', '2', 'have', '2']
# home
# ['hey', 'congrat', '2u2', 'would', 'luv', '2', 'have', '2', 'home']
# dear where you. call me
# dear
# ['dear']
# xy trying smth now. u eat already? we havent...
# xy
# ['xy']
# trying
# ['xy', 'try']
# smth
# ['xy', 'try', 'smth']
# u
# ['xy', 'try', 'smth', 'u']
# eat
# ['xy', 'try', 'smth', 'u', 'eat']
# nt
# ['xy', 'try', 'smth', 'u', 'eat', 'not']
# urgent! please call 09061213237 from landline. å£5000 cash or a luxury 4* canary islands holiday await collection. t&cs sae po box 177. m227xy. 150ppm. 16+
# urgent
# ['urgent']
# 09061213237
# ['urgent', '09061213237']
# landline
# ['urgent', '09061213237', 'landline']
# å£5000
# ['urgent', '09061213237', 'landline', 'å£5000']
# cash
# ['urgent', '09061213237', 'landline', 'å£5000', 'cash']
# luxury
# ['urgent', '09061213237', 'landline', 'å£5000', 'cash', 'luxury']
# 4
# ['urgent', '09061213237', 'landline', 'å£5000', 'cash', 'luxury', '4']
# canary
# ['urgent', '09061213237', 'landline', 'å£5000', 'cash', 'luxury', '4', 'canary']
# islands
# ['urgent', '09061213237', 'landline', 'å£5000', 'cash', 'luxury', '4', 'canary', 'island']
# holiday
# ['urgent', '09061213237', 'landline', 'å£5000', 'cash', 'luxury', '4', 'canary', 'island', 'holiday']
# await
# ['urgent', '09061213237', 'landline', 'å£5000', 'cash', 'luxury', '4', 'canary', 'island', 'holiday', 'await']
# collection
# ['urgent', '09061213237', 'landline', 'å£5000', 'cash', 'luxury', '4', 'canary', 'island', 'holiday', 'await', 'collection']
# t&cs
# ['urgent', '09061213237', 'landline', 'å£5000', 'cash', 'luxury', '4', 'canary', 'island', 'holiday', 'await', 'collection', 't&cs']
# sae
# ['urgent', '09061213237', 'landline', 'å£5000', 'cash', 'luxury', '4', 'canary', 'island', 'holiday', 'await', 'collection', 't&cs', 'sae']
# po
# ['urgent', '09061213237', 'landline', 'å£5000', 'cash', 'luxury', '4', 'canary', 'island', 'holiday', 'await', 'collection', 't&cs', 'sae', 'po']
# box
# ['urgent', '09061213237', 'landline', 'å£5000', 'cash', 'luxury', '4', 'canary', 'island', 'holiday', 'await', 'collection', 't&cs', 'sae', 'po', 'box']
# 177
# ['urgent', '09061213237', 'landline', 'å£5000', 'cash', 'luxury', '4', 'canary', 'island', 'holiday', 'await', 'collection', 't&cs', 'sae', 'po', 'box', '177']
# m227xy
# ['urgent', '09061213237', 'landline', 'å£5000', 'cash', 'luxury', '4', 'canary', 'island', 'holiday', 'await', 'collection', 't&cs', 'sae', 'po', 'box', '177', 'm227xy']
# 150ppm
# ['urgent', '09061213237', 'landline', 'å£5000', 'cash', 'luxury', '4', 'canary', 'island', 'holiday', 'await', 'collection', 't&cs', 'sae', 'po', 'box', '177', 'm227xy', '150ppm']
# 16
# ['urgent', '09061213237', 'landline', 'å£5000', 'cash', 'luxury', '4', 'canary', 'island', 'holiday', 'await', 'collection', 't&cs', 'sae', 'po', 'box', '177', 'm227xy', '150ppm', '16']
# +
# ['urgent', '09061213237', 'landline', 'å£5000', 'cash', 'luxury', '4', 'canary', 'island', 'holiday', 'await', 'collection', 't&cs', 'sae', 'po', 'box', '177', 'm227xy', '150ppm', '16', '+']
# i donno its in your genes or something
# donno
# ['donno']
# genes
# ['donno', 'gene']
# xmas iscoming & ur awarded either å£500 cd gift vouchers & free entry 2 r å£100 weekly draw txt music to 87066 tnc www.ldew.com1win150ppmx3age16subscription
# xmas
# ['xmas']
# iscoming
# ['xmas', 'iscoming']
# ur
# ['xmas', 'iscoming', 'ur']
# awarded
# ['xmas', 'iscoming', 'ur', 'award']
# å£500
# ['xmas', 'iscoming', 'ur', 'award', 'å£500']
# cd
# ['xmas', 'iscoming', 'ur', 'award', 'å£500', 'cd']
# gift
# ['xmas', 'iscoming', 'ur', 'award', 'å£500', 'cd', 'gift']
# vouchers
# ['xmas', 'iscoming', 'ur', 'award', 'å£500', 'cd', 'gift', 'voucher']
# free
# ['xmas', 'iscoming', 'ur', 'award', 'å£500', 'cd', 'gift', 'voucher', 'free']
# entry
# ['xmas', 'iscoming', 'ur', 'award', 'å£500', 'cd', 'gift', 'voucher', 'free', 'entry']
# 2
# ['xmas', 'iscoming', 'ur', 'award', 'å£500', 'cd', 'gift', 'voucher', 'free', 'entry', '2']
# r
# ['xmas', 'iscoming', 'ur', 'award', 'å£500', 'cd', 'gift', 'voucher', 'free', 'entry', '2', 'r']
# å£100
# ['xmas', 'iscoming', 'ur', 'award', 'å£500', 'cd', 'gift', 'voucher', 'free', 'entry', '2', 'r', 'å£100']
# weekly
# ['xmas', 'iscoming', 'ur', 'award', 'å£500', 'cd', 'gift', 'voucher', 'free', 'entry', '2', 'r', 'å£100', 'weekly']
# draw
# ['xmas', 'iscoming', 'ur', 'award', 'å£500', 'cd', 'gift', 'voucher', 'free', 'entry', '2', 'r', 'å£100', 'weekly', 'draw']
# txt
# ['xmas', 'iscoming', 'ur', 'award', 'å£500', 'cd', 'gift', 'voucher', 'free', 'entry', '2', 'r', 'å£100', 'weekly', 'draw', 'txt']
# music
# ['xmas', 'iscoming', 'ur', 'award', 'å£500', 'cd', 'gift', 'voucher', 'free', 'entry', '2', 'r', 'å£100', 'weekly', 'draw', 'txt', 'music']
# 87066
# ['xmas', 'iscoming', 'ur', 'award', 'å£500', 'cd', 'gift', 'voucher', 'free', 'entry', '2', 'r', 'å£100', 'weekly', 'draw', 'txt', 'music', '87066']
# tnc
# ['xmas', 'iscoming', 'ur', 'award', 'å£500', 'cd', 'gift', 'voucher', 'free', 'entry', '2', 'r', 'å£100', 'weekly', 'draw', 'txt', 'music', '87066', 'tnc']
# www.ldew.com1win150ppmx3age16subscription
# ['xmas', 'iscoming', 'ur', 'award', 'å£500', 'cd', 'gift', 'voucher', 'free', 'entry', '2', 'r', 'å£100', 'weekly', 'draw', 'txt', 'music', '87066', 'tnc', 'www.ldew.com1win150ppmx3age16subscription']
# alex says he's not ok with you not being ok with it
# alex
# ['alex']
# says
# ['alex', 'say']
# ok
# ['alex', 'say', 'ok']
# ok
# ['alex', 'say', 'ok', 'ok']
# are u coming to the funeral home
# u
# ['u']
# coming
# ['u', 'come']
# funeral
# ['u', 'come', 'funeral']
# home
# ['u', 'come', 'funeral', 'home']
# my darling sister. how are you doing. when's school resuming. is there a minimum wait period before you reapply? do take care
# darling
# ['darling']
# sister
# ['darling', 'sister']
# school
# ['darling', 'sister', 'school']
# resuming
# ['darling', 'sister', 'school', 'resume']
# minimum
# ['darling', 'sister', 'school', 'resume', 'minimum']
# wait
# ['darling', 'sister', 'school', 'resume', 'minimum', 'wait']
# period
# ['darling', 'sister', 'school', 'resume', 'minimum', 'wait', 'period']
# reapply
# ['darling', 'sister', 'school', 'resume', 'minimum', 'wait', 'period', 'reapply']
# care
# ['darling', 'sister', 'school', 'resume', 'minimum', 'wait', 'period', 'reapply', 'care']
# i.ll hand her my phone to chat wit u
# i.ll
# ['i.ll']
# hand
# ['i.ll', 'hand']
# phone
# ['i.ll', 'hand', 'phone']
# chat
# ['i.ll', 'hand', 'phone', 'chat']
# wit
# ['i.ll', 'hand', 'phone', 'chat', 'wit']
# u
# ['i.ll', 'hand', 'phone', 'chat', 'wit', 'u']
# well good morning mr . hows london treatin' ya treacle?
# good
# ['good']
# morning
# ['good', 'morning']
# mr
# ['good', 'morning', 'mr']
# s
# ['good', 'morning', 'mr', 's']
# london
# ['good', 'morning', 'mr', 's', 'london']
# treatin
# ['good', 'morning', 'mr', 's', 'london', 'treatin']
# ya
# ['good', 'morning', 'mr', 's', 'london', 'treatin', 'ya']
# treacle
# ['good', 'morning', 'mr', 's', 'london', 'treatin', 'ya', 'treacle']
# i can't make it tonight
# tonight
# ['tonight']
# at what time should i come tomorrow
# time
# ['time']
# come
# ['time', 'come']
# tomorrow
# ['time', 'come', 'tomorrow']
# about  &lt;#&gt; bucks. the banks fees are fixed. better to call the bank and find out.
#
# [' ']
# lt;#&gt
# [' ', 'lt;#&gt']
# bucks
# [' ', 'lt;#&gt', 'buck']
# banks
# [' ', 'lt;#&gt', 'buck', 'bank']
# fees
# [' ', 'lt;#&gt', 'buck', 'bank', 'fee']
# fixed
# [' ', 'lt;#&gt', 'buck', 'bank', 'fee', 'fix']
# better
# [' ', 'lt;#&gt', 'buck', 'bank', 'fee', 'fix', 'well']
# bank
# [' ', 'lt;#&gt', 'buck', 'bank', 'fee', 'fix', 'well', 'bank']
# find
# [' ', 'lt;#&gt', 'buck', 'bank', 'fee', 'fix', 'well', 'bank', 'find']
# i can. but it will tell quite long, cos i haven't finish my film yet...
# tell
# ['tell']
# long
# ['tell', 'long']
# cos
# ['tell', 'long', 'cos']
# finish
# ['tell', 'long', 'cos', 'finish']
# film
# ['tell', 'long', 'cos', 'finish', 'film']
# pls ask macho how much is budget for bb bold 2 is cos i saw a new one for  &lt;#&gt;  dollars.
# pls
# ['pls']
# ask
# ['pls', 'ask']
# macho
# ['pls', 'ask', 'macho']
# budget
# ['pls', 'ask', 'macho', 'budget']
# bb
# ['pls', 'ask', 'macho', 'budget', 'bb']
# bold
# ['pls', 'ask', 'macho', 'budget', 'bb', 'bold']
# 2
# ['pls', 'ask', 'macho', 'budget', 'bb', 'bold', '2']
# cos
# ['pls', 'ask', 'macho', 'budget', 'bb', 'bold', '2', 'cos']
# saw
# ['pls', 'ask', 'macho', 'budget', 'bb', 'bold', '2', 'cos', 'see']
# new
# ['pls', 'ask', 'macho', 'budget', 'bb', 'bold', '2', 'cos', 'see', 'new']
#
# ['pls', 'ask', 'macho', 'budget', 'bb', 'bold', '2', 'cos', 'see', 'new', ' ']
# lt;#&gt
# ['pls', 'ask', 'macho', 'budget', 'bb', 'bold', '2', 'cos', 'see', 'new', ' ', 'lt;#&gt']
#
# ['pls', 'ask', 'macho', 'budget', 'bb', 'bold', '2', 'cos', 'see', 'new', ' ', 'lt;#&gt', ' ']
# dollars
# ['pls', 'ask', 'macho', 'budget', 'bb', 'bold', '2', 'cos', 'see', 'new', ' ', 'lt;#&gt', ' ', 'dollar']
# \hi missed your call and my mumhas beendropping red wine all over theplace! what is your adress?\""
# \hi
# ['\\hi']
# missed
# ['\\hi', 'miss']
# mumhas
# ['\\hi', 'miss', 'mumha']
# beendropping
# ['\\hi', 'miss', 'mumha', 'beendroppe']
# red
# ['\\hi', 'miss', 'mumha', 'beendroppe', 'red']
# wine
# ['\\hi', 'miss', 'mumha', 'beendroppe', 'red', 'wine']
# theplace
# ['\\hi', 'miss', 'mumha', 'beendroppe', 'red', 'wine', 'theplace']
# adress?\
# ['\\hi', 'miss', 'mumha', 'beendroppe', 'red', 'wine', 'theplace', 'adress?\\']
# ill be at yours in about 3 mins but look out for me
# ill
# ['ill']
# 3
# ['ill', '3']
# mins
# ['ill', '3', 'min']
# look
# ['ill', '3', 'min', 'look']
# what you did in  leave.
#
# [' ']
# leave
# [' ', 'leave']
# i'm coming back on thursday. yay. is it gonna be ok to get the money. cheers. oh yeah and how are you. everything alright. hows school. or do you call it work now
# coming
# ['come']
# thursday
# ['come', 'thursday']
# yay
# ['come', 'thursday', 'yay']
# gon
# ['come', 'thursday', 'yay', 'go']
# na
# ['come', 'thursday', 'yay', 'go', 'to']
# ok
# ['come', 'thursday', 'yay', 'go', 'to', 'ok']
# money
# ['come', 'thursday', 'yay', 'go', 'to', 'ok', 'money']
# cheers
# ['come', 'thursday', 'yay', 'go', 'to', 'ok', 'money', 'cheer']
# oh
# ['come', 'thursday', 'yay', 'go', 'to', 'ok', 'money', 'cheer', 'oh']
# yeah
# ['come', 'thursday', 'yay', 'go', 'to', 'ok', 'money', 'cheer', 'oh', 'yeah']
# alright
# ['come', 'thursday', 'yay', 'go', 'to', 'ok', 'money', 'cheer', 'oh', 'yeah', 'alright']
# s
# ['come', 'thursday', 'yay', 'go', 'to', 'ok', 'money', 'cheer', 'oh', 'yeah', 'alright', 's']
# school
# ['come', 'thursday', 'yay', 'go', 'to', 'ok', 'money', 'cheer', 'oh', 'yeah', 'alright', 's', 'school']
# work
# ['come', 'thursday', 'yay', 'go', 'to', 'ok', 'money', 'cheer', 'oh', 'yeah', 'alright', 's', 'school', 'work']
# jolly good! by the way,  will give u tickets for sat eve 7.30. speak before then x
# jolly
# ['jolly']
# good
# ['jolly', 'good']
# way
# ['jolly', 'good', 'way']
#
# ['jolly', 'good', 'way', ' ']
# u
# ['jolly', 'good', 'way', ' ', 'u']
# tickets
# ['jolly', 'good', 'way', ' ', 'u', 'ticket']
# sat
# ['jolly', 'good', 'way', ' ', 'u', 'ticket', 'sat']
# eve
# ['jolly', 'good', 'way', ' ', 'u', 'ticket', 'sat', 'eve']
# 7.30
# ['jolly', 'good', 'way', ' ', 'u', 'ticket', 'sat', 'eve', '7.30']
# speak
# ['jolly', 'good', 'way', ' ', 'u', 'ticket', 'sat', 'eve', '7.30', 'speak']
# x
# ['jolly', 'good', 'way', ' ', 'u', 'ticket', 'sat', 'eve', '7.30', 'speak', 'x']
# yeah, that's what i was thinking
# yeah
# ['yeah']
# thinking
# ['yeah', 'think']
# k.k:)i'm going to tirunelvali this week to see my uncle ..i already spend the amount by taking dress .so only i want money.i will give it on feb 1
# k.k:)i'm
# ["k.k:)i'm"]
# going
# ["k.k:)i'm", 'go']
# tirunelvali
# ["k.k:)i'm", 'go', 'tirunelvali']
# week
# ["k.k:)i'm", 'go', 'tirunelvali', 'week']
# uncle
# ["k.k:)i'm", 'go', 'tirunelvali', 'week', 'uncle']
# spend
# ["k.k:)i'm", 'go', 'tirunelvali', 'week', 'uncle', 'spend']
# taking
# ["k.k:)i'm", 'go', 'tirunelvali', 'week', 'uncle', 'spend', 'take']
# dress
# ["k.k:)i'm", 'go', 'tirunelvali', 'week', 'uncle', 'spend', 'take', 'dress']
# .so
# ["k.k:)i'm", 'go', 'tirunelvali', 'week', 'uncle', 'spend', 'take', 'dress', '.so']
# want
# ["k.k:)i'm", 'go', 'tirunelvali', 'week', 'uncle', 'spend', 'take', 'dress', '.so', 'want']
# money.i
# ["k.k:)i'm", 'go', 'tirunelvali', 'week', 'uncle', 'spend', 'take', 'dress', '.so', 'want', 'money.i']
# feb
# ["k.k:)i'm", 'go', 'tirunelvali', 'week', 'uncle', 'spend', 'take', 'dress', '.so', 'want', 'money.i', 'feb']
# 1
# ["k.k:)i'm", 'go', 'tirunelvali', 'week', 'uncle', 'spend', 'take', 'dress', '.so', 'want', 'money.i', 'feb', '1']
# here got ur favorite oyster... n got my favorite sashimi... ok lar i dun say already... wait ur stomach start rumbling...
# got
# ['get']
# ur
# ['get', 'ur']
# favorite
# ['get', 'ur', 'favorite']
# oyster
# ['get', 'ur', 'favorite', 'oyster']
# n
# ['get', 'ur', 'favorite', 'oyster', 'n']
# got
# ['get', 'ur', 'favorite', 'oyster', 'n', 'get']
# favorite
# ['get', 'ur', 'favorite', 'oyster', 'n', 'get', 'favorite']
# sashimi
# ['get', 'ur', 'favorite', 'oyster', 'n', 'get', 'favorite', 'sashimi']
# ok
# ['get', 'ur', 'favorite', 'oyster', 'n', 'get', 'favorite', 'sashimi', 'ok']
# lar
# ['get', 'ur', 'favorite', 'oyster', 'n', 'get', 'favorite', 'sashimi', 'ok', 'lar']
# dun
# ['get', 'ur', 'favorite', 'oyster', 'n', 'get', 'favorite', 'sashimi', 'ok', 'lar', 'dun']
# wait
# ['get', 'ur', 'favorite', 'oyster', 'n', 'get', 'favorite', 'sashimi', 'ok', 'lar', 'dun', 'wait']
# ur
# ['get', 'ur', 'favorite', 'oyster', 'n', 'get', 'favorite', 'sashimi', 'ok', 'lar', 'dun', 'wait', 'ur']
# stomach
# ['get', 'ur', 'favorite', 'oyster', 'n', 'get', 'favorite', 'sashimi', 'ok', 'lar', 'dun', 'wait', 'ur', 'stomach']
# start
# ['get', 'ur', 'favorite', 'oyster', 'n', 'get', 'favorite', 'sashimi', 'ok', 'lar', 'dun', 'wait', 'ur', 'stomach', 'start']
# rumbling
# ['get', 'ur', 'favorite', 'oyster', 'n', 'get', 'favorite', 'sashimi', 'ok', 'lar', 'dun', 'wait', 'ur', 'stomach', 'start', 'rumble']
# my sister going to earn more than me da.
# sister
# ['sister']
# going
# ['sister', 'go']
# earn
# ['sister', 'go', 'earn']
# da
# ['sister', 'go', 'earn', 'da']
# get the official england poly ringtone or colour flag on yer mobile for tonights game! text tone or flag to 84199. optout txt eng stop box39822 w111wx å£1.50
# official
# ['official']
# england
# ['official', 'england']
# poly
# ['official', 'england', 'poly']
# ringtone
# ['official', 'england', 'poly', 'ringtone']
# colour
# ['official', 'england', 'poly', 'ringtone', 'colour']
# flag
# ['official', 'england', 'poly', 'ringtone', 'colour', 'flag']
# yer
# ['official', 'england', 'poly', 'ringtone', 'colour', 'flag', 'yer']
# mobile
# ['official', 'england', 'poly', 'ringtone', 'colour', 'flag', 'yer', 'mobile']
# tonights
# ['official', 'england', 'poly', 'ringtone', 'colour', 'flag', 'yer', 'mobile', 'tonight']
# game
# ['official', 'england', 'poly', 'ringtone', 'colour', 'flag', 'yer', 'mobile', 'tonight', 'game']
# text
# ['official', 'england', 'poly', 'ringtone', 'colour', 'flag', 'yer', 'mobile', 'tonight', 'game', 'text']
# tone
# ['official', 'england', 'poly', 'ringtone', 'colour', 'flag', 'yer', 'mobile', 'tonight', 'game', 'text', 'tone']
# flag
# ['official', 'england', 'poly', 'ringtone', 'colour', 'flag', 'yer', 'mobile', 'tonight', 'game', 'text', 'tone', 'flag']
# 84199
# ['official', 'england', 'poly', 'ringtone', 'colour', 'flag', 'yer', 'mobile', 'tonight', 'game', 'text', 'tone', 'flag', '84199']
# optout
# ['official', 'england', 'poly', 'ringtone', 'colour', 'flag', 'yer', 'mobile', 'tonight', 'game', 'text', 'tone', 'flag', '84199', 'optout']
# txt
# ['official', 'england', 'poly', 'ringtone', 'colour', 'flag', 'yer', 'mobile', 'tonight', 'game', 'text', 'tone', 'flag', '84199', 'optout', 'txt']
# eng
# ['official', 'england', 'poly', 'ringtone', 'colour', 'flag', 'yer', 'mobile', 'tonight', 'game', 'text', 'tone', 'flag', '84199', 'optout', 'txt', 'eng']
# stop
# ['official', 'england', 'poly', 'ringtone', 'colour', 'flag', 'yer', 'mobile', 'tonight', 'game', 'text', 'tone', 'flag', '84199', 'optout', 'txt', 'eng', 'stop']
# box39822
# ['official', 'england', 'poly', 'ringtone', 'colour', 'flag', 'yer', 'mobile', 'tonight', 'game', 'text', 'tone', 'flag', '84199', 'optout', 'txt', 'eng', 'stop', 'box39822']
# w111wx
# ['official', 'england', 'poly', 'ringtone', 'colour', 'flag', 'yer', 'mobile', 'tonight', 'game', 'text', 'tone', 'flag', '84199', 'optout', 'txt', 'eng', 'stop', 'box39822', 'w111wx']
# å£1.50
# ['official', 'england', 'poly', 'ringtone', 'colour', 'flag', 'yer', 'mobile', 'tonight', 'game', 'text', 'tone', 'flag', '84199', 'optout', 'txt', 'eng', 'stop', 'box39822', 'w111wx', 'å£1.50']
# hahaha..use your brain dear
# hahaha
# ['hahaha']
# use
# ['hahaha', 'use']
# brain
# ['hahaha', 'use', 'brain']
# dear
# ['hahaha', 'use', 'brain', 'dear']
# jus finish watching tv... u?
# jus
# ['jus']
# finish
# ['jus', 'finish']
# watching
# ['jus', 'finish', 'watch']
# tv
# ['jus', 'finish', 'watch', 'tv']
# u
# ['jus', 'finish', 'watch', 'tv', 'u']
# k, fyi i'm back in my parents' place in south tampa so i might need to do the deal somewhere else
# k
# ['k']
# fyi
# ['k', 'fyi']
# parents
# ['k', 'fyi', 'parent']
# place
# ['k', 'fyi', 'parent', 'place']
# south
# ['k', 'fyi', 'parent', 'place', 'south']
# tampa
# ['k', 'fyi', 'parent', 'place', 'south', 'tampa']
# need
# ['k', 'fyi', 'parent', 'place', 'south', 'tampa', 'need']
# deal
# ['k', 'fyi', 'parent', 'place', 'south', 'tampa', 'need', 'deal']
# good morning, my love ... i go to sleep now and wish you a great day full of feeling better and opportunity ... you are my last thought babe, i love you *kiss*
# good
# ['good']
# morning
# ['good', 'morning']
# love
# ['good', 'morning', 'love']
# sleep
# ['good', 'morning', 'love', 'sleep']
# wish
# ['good', 'morning', 'love', 'sleep', 'wish']
# great
# ['good', 'morning', 'love', 'sleep', 'wish', 'great']
# day
# ['good', 'morning', 'love', 'sleep', 'wish', 'great', 'day']
# feeling
# ['good', 'morning', 'love', 'sleep', 'wish', 'great', 'day', 'feel']
# better
# ['good', 'morning', 'love', 'sleep', 'wish', 'great', 'day', 'feel', 'well']
# opportunity
# ['good', 'morning', 'love', 'sleep', 'wish', 'great', 'day', 'feel', 'well', 'opportunity']
# thought
# ['good', 'morning', 'love', 'sleep', 'wish', 'great', 'day', 'feel', 'well', 'opportunity', 'thought']
# babe
# ['good', 'morning', 'love', 'sleep', 'wish', 'great', 'day', 'feel', 'well', 'opportunity', 'thought', 'babe']
# love
# ['good', 'morning', 'love', 'sleep', 'wish', 'great', 'day', 'feel', 'well', 'opportunity', 'thought', 'babe', 'love']
# kiss
# ['good', 'morning', 'love', 'sleep', 'wish', 'great', 'day', 'feel', 'well', 'opportunity', 'thought', 'babe', 'love', 'kiss']
# kothi print out marandratha.
# kothi
# ['kothi']
# print
# ['kothi', 'print']
# marandratha
# ['kothi', 'print', 'marandratha']
# but we havent got da topic yet rite?
# nt
# ['not']
# got
# ['not', 'get']
# da
# ['not', 'get', 'da']
# topic
# ['not', 'get', 'da', 'topic']
# rite
# ['not', 'get', 'da', 'topic', 'rite']
# ok no problem... yup i'm going to sch at 4 if i rem correctly...
# ok
# ['ok']
# problem
# ['ok', 'problem']
# yup
# ['ok', 'problem', 'yup']
# going
# ['ok', 'problem', 'yup', 'go']
# sch
# ['ok', 'problem', 'yup', 'go', 'sch']
# 4
# ['ok', 'problem', 'yup', 'go', 'sch', '4']
# rem
# ['ok', 'problem', 'yup', 'go', 'sch', '4', 'rem']
# correctly
# ['ok', 'problem', 'yup', 'go', 'sch', '4', 'rem', 'correctly']
# thanks, i'll keep that in mind
# thanks
# ['thanks']
# mind
# ['thanks', 'mind']
# aah bless! how's your arm?
# aah
# ['aah']
# bless
# ['aah', 'bless']
# arm
# ['aah', 'bless', 'arm']
# dear sir,salam alaikkum.pride and pleasure meeting you today at the tea shop.we are pleased to send you our contact number at qatar.rakhesh an indian.pls save our number.respectful regards.
# dear
# ['dear']
# sir
# ['dear', 'sir']
# salam
# ['dear', 'sir', 'salam']
# alaikkum.pride
# ['dear', 'sir', 'salam', 'alaikkum.pride']
# pleasure
# ['dear', 'sir', 'salam', 'alaikkum.pride', 'pleasure']
# meeting
# ['dear', 'sir', 'salam', 'alaikkum.pride', 'pleasure', 'meeting']
# today
# ['dear', 'sir', 'salam', 'alaikkum.pride', 'pleasure', 'meeting', 'today']
# tea
# ['dear', 'sir', 'salam', 'alaikkum.pride', 'pleasure', 'meeting', 'today', 'tea']
# shop.we
# ['dear', 'sir', 'salam', 'alaikkum.pride', 'pleasure', 'meeting', 'today', 'tea', 'shop.we']
# pleased
# ['dear', 'sir', 'salam', 'alaikkum.pride', 'pleasure', 'meeting', 'today', 'tea', 'shop.we', 'pleased']
# send
# ['dear', 'sir', 'salam', 'alaikkum.pride', 'pleasure', 'meeting', 'today', 'tea', 'shop.we', 'pleased', 'send']
# contact
# ['dear', 'sir', 'salam', 'alaikkum.pride', 'pleasure', 'meeting', 'today', 'tea', 'shop.we', 'pleased', 'send', 'contact']
# number
# ['dear', 'sir', 'salam', 'alaikkum.pride', 'pleasure', 'meeting', 'today', 'tea', 'shop.we', 'pleased', 'send', 'contact', 'number']
# qatar.rakhesh
# ['dear', 'sir', 'salam', 'alaikkum.pride', 'pleasure', 'meeting', 'today', 'tea', 'shop.we', 'pleased', 'send', 'contact', 'number', 'qatar.rakhesh']
# indian.pls
# ['dear', 'sir', 'salam', 'alaikkum.pride', 'pleasure', 'meeting', 'today', 'tea', 'shop.we', 'pleased', 'send', 'contact', 'number', 'qatar.rakhesh', 'indian.pls']
# save
# ['dear', 'sir', 'salam', 'alaikkum.pride', 'pleasure', 'meeting', 'today', 'tea', 'shop.we', 'pleased', 'send', 'contact', 'number', 'qatar.rakhesh', 'indian.pls', 'save']
# number.respectful
# ['dear', 'sir', 'salam', 'alaikkum.pride', 'pleasure', 'meeting', 'today', 'tea', 'shop.we', 'pleased', 'send', 'contact', 'number', 'qatar.rakhesh', 'indian.pls', 'save', 'number.respectful']
# regards
# ['dear', 'sir', 'salam', 'alaikkum.pride', 'pleasure', 'meeting', 'today', 'tea', 'shop.we', 'pleased', 'send', 'contact', 'number', 'qatar.rakhesh', 'indian.pls', 'save', 'number.respectful', 'regard']
# gal n boy walking in d park. gal-can i hold ur hand? boy-y? do u think i would run away? gal-no, jst wana c how it feels walking in heaven with an prince..gn:-)
# gal
# ['gal']
# n
# ['gal', 'n']
# boy
# ['gal', 'n', 'boy']
# walking
# ['gal', 'n', 'boy', 'walk']
# d
# ['gal', 'n', 'boy', 'walk', 'd']
# park
# ['gal', 'n', 'boy', 'walk', 'd', 'park']
# gal
# ['gal', 'n', 'boy', 'walk', 'd', 'park', 'gal']
# hold
# ['gal', 'n', 'boy', 'walk', 'd', 'park', 'gal', 'hold']
# ur
# ['gal', 'n', 'boy', 'walk', 'd', 'park', 'gal', 'hold', 'ur']
# hand
# ['gal', 'n', 'boy', 'walk', 'd', 'park', 'gal', 'hold', 'ur', 'hand']
# boy
# ['gal', 'n', 'boy', 'walk', 'd', 'park', 'gal', 'hold', 'ur', 'hand', 'boy']
# y
# ['gal', 'n', 'boy', 'walk', 'd', 'park', 'gal', 'hold', 'ur', 'hand', 'boy', 'y']
# u
# ['gal', 'n', 'boy', 'walk', 'd', 'park', 'gal', 'hold', 'ur', 'hand', 'boy', 'y', 'u']
# think
# ['gal', 'n', 'boy', 'walk', 'd', 'park', 'gal', 'hold', 'ur', 'hand', 'boy', 'y', 'u', 'think']
# run
# ['gal', 'n', 'boy', 'walk', 'd', 'park', 'gal', 'hold', 'ur', 'hand', 'boy', 'y', 'u', 'think', 'run']
# away
# ['gal', 'n', 'boy', 'walk', 'd', 'park', 'gal', 'hold', 'ur', 'hand', 'boy', 'y', 'u', 'think', 'run', 'away']
# gal
# ['gal', 'n', 'boy', 'walk', 'd', 'park', 'gal', 'hold', 'ur', 'hand', 'boy', 'y', 'u', 'think', 'run', 'away', 'gal']
# jst
# ['gal', 'n', 'boy', 'walk', 'd', 'park', 'gal', 'hold', 'ur', 'hand', 'boy', 'y', 'u', 'think', 'run', 'away', 'gal', 'jst']
# wana
# ['gal', 'n', 'boy', 'walk', 'd', 'park', 'gal', 'hold', 'ur', 'hand', 'boy', 'y', 'u', 'think', 'run', 'away', 'gal', 'jst', 'wana']
# c
# ['gal', 'n', 'boy', 'walk', 'd', 'park', 'gal', 'hold', 'ur', 'hand', 'boy', 'y', 'u', 'think', 'run', 'away', 'gal', 'jst', 'wana', 'c']
# feels
# ['gal', 'n', 'boy', 'walk', 'd', 'park', 'gal', 'hold', 'ur', 'hand', 'boy', 'y', 'u', 'think', 'run', 'away', 'gal', 'jst', 'wana', 'c', 'feel']
# walking
# ['gal', 'n', 'boy', 'walk', 'd', 'park', 'gal', 'hold', 'ur', 'hand', 'boy', 'y', 'u', 'think', 'run', 'away', 'gal', 'jst', 'wana', 'c', 'feel', 'walk']
# heaven
# ['gal', 'n', 'boy', 'walk', 'd', 'park', 'gal', 'hold', 'ur', 'hand', 'boy', 'y', 'u', 'think', 'run', 'away', 'gal', 'jst', 'wana', 'c', 'feel', 'walk', 'heaven']
# prince
# ['gal', 'n', 'boy', 'walk', 'd', 'park', 'gal', 'hold', 'ur', 'hand', 'boy', 'y', 'u', 'think', 'run', 'away', 'gal', 'jst', 'wana', 'c', 'feel', 'walk', 'heaven', 'prince']
# gn:-
# ['gal', 'n', 'boy', 'walk', 'd', 'park', 'gal', 'hold', 'ur', 'hand', 'boy', 'y', 'u', 'think', 'run', 'away', 'gal', 'jst', 'wana', 'c', 'feel', 'walk', 'heaven', 'prince', 'gn:-']
# what makes you most happy?
# makes
# ['make']
# happy
# ['make', 'happy']
# wishing you a wonderful week.
# wishing
# ['wish']
# wonderful
# ['wish', 'wonderful']
# week
# ['wish', 'wonderful', 'week']
# sweet heart how are you?
# sweet
# ['sweet']
# heart
# ['sweet', 'heart']
# sir, waiting for your letter.
# sir
# ['sir']
# waiting
# ['sir', 'wait']
# letter
# ['sir', 'wait', 'letter']
# dude im no longer a pisces. im an aquarius now.
# dude
# ['dude']
# m
# ['dude', 'be']
# longer
# ['dude', 'be', 'longer']
# pisces
# ['dude', 'be', 'longer', 'pisce']
# m
# ['dude', 'be', 'longer', 'pisce', 'be']
# aquarius
# ['dude', 'be', 'longer', 'pisce', 'be', 'aquarius']
# x course it 2yrs. just so her messages on messenger lik you r sending me
# x
# ['x']
# course
# ['x', 'course']
# 2yrs
# ['x', 'course', '2yrs']
# messages
# ['x', 'course', '2yrs', 'message']
# messenger
# ['x', 'course', '2yrs', 'message', 'messenger']
# lik
# ['x', 'course', '2yrs', 'message', 'messenger', 'lik']
# r
# ['x', 'course', '2yrs', 'message', 'messenger', 'lik', 'r']
# sending
# ['x', 'course', '2yrs', 'message', 'messenger', 'lik', 'r', 'send']
# i think steyn surely get one wicket:)
# think
# ['think']
# steyn
# ['think', 'steyn']
# surely
# ['think', 'steyn', 'surely']
# wicket
# ['think', 'steyn', 'surely', 'wicket']
# neither [in sterm voice] - i'm studying. all fine with me! not sure the  thing will be resolved, tho. anyway. have a fab hols
# sterm
# ['sterm']
# voice
# ['sterm', 'voice']
# studying
# ['sterm', 'voice', 'study']
# fine
# ['sterm', 'voice', 'study', 'fine']
# sure
# ['sterm', 'voice', 'study', 'fine', 'sure']
#
# ['sterm', 'voice', 'study', 'fine', 'sure', ' ']
# thing
# ['sterm', 'voice', 'study', 'fine', 'sure', ' ', 'thing']
# resolved
# ['sterm', 'voice', 'study', 'fine', 'sure', ' ', 'thing', 'resolve']
# tho
# ['sterm', 'voice', 'study', 'fine', 'sure', ' ', 'thing', 'resolve', 'tho']
# fab
# ['sterm', 'voice', 'study', 'fine', 'sure', ' ', 'thing', 'resolve', 'tho', 'fab']
# hols
# ['sterm', 'voice', 'study', 'fine', 'sure', ' ', 'thing', 'resolve', 'tho', 'fab', 'hols']
# garbage bags, eggs, jam, bread, hannaford wheat chex
# garbage
# ['garbage']
# bags
# ['garbage', 'bag']
# eggs
# ['garbage', 'bag', 'egg']
# jam
# ['garbage', 'bag', 'egg', 'jam']
# bread
# ['garbage', 'bag', 'egg', 'jam', 'bread']
# hannaford
# ['garbage', 'bag', 'egg', 'jam', 'bread', 'hannaford']
# wheat
# ['garbage', 'bag', 'egg', 'jam', 'bread', 'hannaford', 'wheat']
# chex
# ['garbage', 'bag', 'egg', 'jam', 'bread', 'hannaford', 'wheat', 'chex']
# no. it's not pride. i'm almost  &lt;#&gt;  years old and shouldn't be takin money from my kid. you're not supposed to have to deal with this stuff. this is grownup stuff--why i don't tell you.
# pride
# ['pride']
#
# ['pride', ' ']
# lt;#&gt
# ['pride', ' ', 'lt;#&gt']
#
# ['pride', ' ', 'lt;#&gt', ' ']
# years
# ['pride', ' ', 'lt;#&gt', ' ', 'year']
# old
# ['pride', ' ', 'lt;#&gt', ' ', 'year', 'old']
# takin
# ['pride', ' ', 'lt;#&gt', ' ', 'year', 'old', 'takin']
# money
# ['pride', ' ', 'lt;#&gt', ' ', 'year', 'old', 'takin', 'money']
# kid
# ['pride', ' ', 'lt;#&gt', ' ', 'year', 'old', 'takin', 'money', 'kid']
# supposed
# ['pride', ' ', 'lt;#&gt', ' ', 'year', 'old', 'takin', 'money', 'kid', 'suppose']
# deal
# ['pride', ' ', 'lt;#&gt', ' ', 'year', 'old', 'takin', 'money', 'kid', 'suppose', 'deal']
# stuff
# ['pride', ' ', 'lt;#&gt', ' ', 'year', 'old', 'takin', 'money', 'kid', 'suppose', 'deal', 'stuff']
# grownup
# ['pride', ' ', 'lt;#&gt', ' ', 'year', 'old', 'takin', 'money', 'kid', 'suppose', 'deal', 'stuff', 'grownup']
# stuff
# ['pride', ' ', 'lt;#&gt', ' ', 'year', 'old', 'takin', 'money', 'kid', 'suppose', 'deal', 'stuff', 'grownup', 'stuff']
# tell
# ['pride', ' ', 'lt;#&gt', ' ', 'year', 'old', 'takin', 'money', 'kid', 'suppose', 'deal', 'stuff', 'grownup', 'stuff', 'tell']
# sounds better than my evening im just doing my costume. im not sure what time i finish tomorrow but i will txt you at the end.
# sounds
# ['sound']
# better
# ['sound', 'well']
# evening
# ['sound', 'well', 'evening']
# m
# ['sound', 'well', 'evening', 'be']
# costume
# ['sound', 'well', 'evening', 'be', 'costume']
# m
# ['sound', 'well', 'evening', 'be', 'costume', 'be']
# sure
# ['sound', 'well', 'evening', 'be', 'costume', 'be', 'sure']
# time
# ['sound', 'well', 'evening', 'be', 'costume', 'be', 'sure', 'time']
# finish
# ['sound', 'well', 'evening', 'be', 'costume', 'be', 'sure', 'time', 'finish']
# tomorrow
# ['sound', 'well', 'evening', 'be', 'costume', 'be', 'sure', 'time', 'finish', 'tomorrow']
# txt
# ['sound', 'well', 'evening', 'be', 'costume', 'be', 'sure', 'time', 'finish', 'tomorrow', 'txt']
# end
# ['sound', 'well', 'evening', 'be', 'costume', 'be', 'sure', 'time', 'finish', 'tomorrow', 'txt', 'end']
# my birthday is on feb  &lt;#&gt;  da. .
# birthday
# ['birthday']
# feb
# ['birthday', 'feb']
#
# ['birthday', 'feb', ' ']
# lt;#&gt
# ['birthday', 'feb', ' ', 'lt;#&gt']
#
# ['birthday', 'feb', ' ', 'lt;#&gt', ' ']
# da
# ['birthday', 'feb', ' ', 'lt;#&gt', ' ', 'da']
# so when do you wanna gym?
# wanna
# ['wanna']
# gym
# ['wanna', 'gym']
# you'd like that wouldn't you? jerk!
# like
# ['like']
# jerk
# ['like', 'jerk']
# are u awake? is there snow there?
# u
# ['u']
# awake
# ['u', 'awake']
# snow
# ['u', 'awake', 'snow']
# and of course you should make a stink!
# course
# ['course']
# stink
# ['course', 'stink']
# u r subscribed 2 textcomp 250 wkly comp. 1st wk?s free question follows, subsequent wks charged@150p/msg.2 unsubscribe txt stop 2 84128,custcare 08712405020
# u
# ['u']
# r
# ['u', 'r']
# subscribed
# ['u', 'r', 'subscribe']
# 2
# ['u', 'r', 'subscribe', '2']
# textcomp
# ['u', 'r', 'subscribe', '2', 'textcomp']
# 250
# ['u', 'r', 'subscribe', '2', 'textcomp', '250']
# wkly
# ['u', 'r', 'subscribe', '2', 'textcomp', '250', 'wkly']
# comp
# ['u', 'r', 'subscribe', '2', 'textcomp', '250', 'wkly', 'comp']
# 1st
# ['u', 'r', 'subscribe', '2', 'textcomp', '250', 'wkly', 'comp', '1st']
# wk?s
# ['u', 'r', 'subscribe', '2', 'textcomp', '250', 'wkly', 'comp', '1st', 'wk?s']
# free
# ['u', 'r', 'subscribe', '2', 'textcomp', '250', 'wkly', 'comp', '1st', 'wk?s', 'free']
# question
# ['u', 'r', 'subscribe', '2', 'textcomp', '250', 'wkly', 'comp', '1st', 'wk?s', 'free', 'question']
# follows
# ['u', 'r', 'subscribe', '2', 'textcomp', '250', 'wkly', 'comp', '1st', 'wk?s', 'free', 'question', 'follow']
# subsequent
# ['u', 'r', 'subscribe', '2', 'textcomp', '250', 'wkly', 'comp', '1st', 'wk?s', 'free', 'question', 'follow', 'subsequent']
# wks
# ['u', 'r', 'subscribe', '2', 'textcomp', '250', 'wkly', 'comp', '1st', 'wk?s', 'free', 'question', 'follow', 'subsequent', 'wks']
# charged@150p
# ['u', 'r', 'subscribe', '2', 'textcomp', '250', 'wkly', 'comp', '1st', 'wk?s', 'free', 'question', 'follow', 'subsequent', 'wks', 'charged@150p']
# msg.2
# ['u', 'r', 'subscribe', '2', 'textcomp', '250', 'wkly', 'comp', '1st', 'wk?s', 'free', 'question', 'follow', 'subsequent', 'wks', 'charged@150p', 'msg.2']
# unsubscribe
# ['u', 'r', 'subscribe', '2', 'textcomp', '250', 'wkly', 'comp', '1st', 'wk?s', 'free', 'question', 'follow', 'subsequent', 'wks', 'charged@150p', 'msg.2', 'unsubscribe']
# txt
# ['u', 'r', 'subscribe', '2', 'textcomp', '250', 'wkly', 'comp', '1st', 'wk?s', 'free', 'question', 'follow', 'subsequent', 'wks', 'charged@150p', 'msg.2', 'unsubscribe', 'txt']
# stop
# ['u', 'r', 'subscribe', '2', 'textcomp', '250', 'wkly', 'comp', '1st', 'wk?s', 'free', 'question', 'follow', 'subsequent', 'wks', 'charged@150p', 'msg.2', 'unsubscribe', 'txt', 'stop']
# 2
# ['u', 'r', 'subscribe', '2', 'textcomp', '250', 'wkly', 'comp', '1st', 'wk?s', 'free', 'question', 'follow', 'subsequent', 'wks', 'charged@150p', 'msg.2', 'unsubscribe', 'txt', 'stop', '2']
# 84128,custcare
# ['u', 'r', 'subscribe', '2', 'textcomp', '250', 'wkly', 'comp', '1st', 'wk?s', 'free', 'question', 'follow', 'subsequent', 'wks', 'charged@150p', 'msg.2', 'unsubscribe', 'txt', 'stop', '2', '84128,custcare']
# 08712405020
# ['u', 'r', 'subscribe', '2', 'textcomp', '250', 'wkly', 'comp', '1st', 'wk?s', 'free', 'question', 'follow', 'subsequent', 'wks', 'charged@150p', 'msg.2', 'unsubscribe', 'txt', 'stop', '2', '84128,custcare', '08712405020']
# no go. no openings for that room 'til after thanksgiving without an upcharge.
# openings
# ['opening']
# room
# ['opening', 'room']
# til
# ['opening', 'room', 'til']
# thanksgiving
# ['opening', 'room', 'til', 'thanksgive']
# upcharge
# ['opening', 'room', 'til', 'thanksgive', 'upcharge']
# when you guys planning on coming over?
# guys
# ['guy']
# planning
# ['guy', 'plan']
# coming
# ['guy', 'plan', 'come']
# wat ì_ doing now?
# wat
# ['wat']
# ì
# ['wat', 'ì']
# my parents, my kidz, my friends n my colleagues. all screaming.. surprise !! and i was waiting on the sofa.. ... ..... ' naked...!
# parents
# ['parent']
# kidz
# ['parent', 'kidz']
# friends
# ['parent', 'kidz', 'friend']
# n
# ['parent', 'kidz', 'friend', 'n']
# colleagues
# ['parent', 'kidz', 'friend', 'n', 'colleague']
# screaming
# ['parent', 'kidz', 'friend', 'n', 'colleague', 'scream']
# surprise
# ['parent', 'kidz', 'friend', 'n', 'colleague', 'scream', 'surprise']
# waiting
# ['parent', 'kidz', 'friend', 'n', 'colleague', 'scream', 'surprise', 'wait']
# sofa
# ['parent', 'kidz', 'friend', 'n', 'colleague', 'scream', 'surprise', 'wait', 'sofa']
# naked
# ['parent', 'kidz', 'friend', 'n', 'colleague', 'scream', 'surprise', 'wait', 'sofa', 'naked']
# no sir. that's why i had an 8-hr trip on the bus last week. have another audition next wednesday but i think i might drive this time.
# sir
# ['sir']
# 8-hr
# ['sir', '8-hr']
# trip
# ['sir', '8-hr', 'trip']
# bus
# ['sir', '8-hr', 'trip', 'bus']
# week
# ['sir', '8-hr', 'trip', 'bus', 'week']
# audition
# ['sir', '8-hr', 'trip', 'bus', 'week', 'audition']
# wednesday
# ['sir', '8-hr', 'trip', 'bus', 'week', 'audition', 'wednesday']
# think
# ['sir', '8-hr', 'trip', 'bus', 'week', 'audition', 'wednesday', 'think']
# drive
# ['sir', '8-hr', 'trip', 'bus', 'week', 'audition', 'wednesday', 'think', 'drive']
# time
# ['sir', '8-hr', 'trip', 'bus', 'week', 'audition', 'wednesday', 'think', 'drive', 'time']
# do i? i thought i put it back in the box
# thought
# ['think']
# box
# ['think', 'box']
# i'm home...
# home
# ['home']
# no one interested. may be some business plan.
# interested
# ['interested']
# business
# ['interested', 'business']
# plan
# ['interested', 'business', 'plan']
# yup it's at paragon... i havent decided whether 2 cut yet... hee...
# yup
# ['yup']
# paragon
# ['yup', 'paragon']
# nt
# ['yup', 'paragon', 'not']
# decided
# ['yup', 'paragon', 'not', 'decide']
# 2
# ['yup', 'paragon', 'not', 'decide', '2']
# cut
# ['yup', 'paragon', 'not', 'decide', '2', 'cut']
# hee
# ['yup', 'paragon', 'not', 'decide', '2', 'cut', 'hee']
# good morning princess! have a great day!
# good
# ['good']
# morning
# ['good', 'morning']
# princess
# ['good', 'morning', 'princess']
# great
# ['good', 'morning', 'princess', 'great']
# day
# ['good', 'morning', 'princess', 'great', 'day']
# guai... ìï shd haf seen him when he's naughty... ìï so free today? can go jogging...
# guai
# ['guai']
# ìï
# ['guai', 'ìï']
# shd
# ['guai', 'ìï', 'shd']
# haf
# ['guai', 'ìï', 'shd', 'haf']
# seen
# ['guai', 'ìï', 'shd', 'haf', 'see']
# naughty
# ['guai', 'ìï', 'shd', 'haf', 'see', 'naughty']
# ìï
# ['guai', 'ìï', 'shd', 'haf', 'see', 'naughty', 'ìï']
# free
# ['guai', 'ìï', 'shd', 'haf', 'see', 'naughty', 'ìï', 'free']
# today
# ['guai', 'ìï', 'shd', 'haf', 'see', 'naughty', 'ìï', 'free', 'today']
# jogging
# ['guai', 'ìï', 'shd', 'haf', 'see', 'naughty', 'ìï', 'free', 'today', 'jog']
# aiyo cos i sms ì_ then ì_ neva reply so i wait 4 ì_ to reply lar. i tot ì_ havent finish ur lab wat.
# aiyo
# ['aiyo']
# cos
# ['aiyo', 'cos']
# sms
# ['aiyo', 'cos', 'sms']
# ì
# ['aiyo', 'cos', 'sms', 'ì']
# ì
# ['aiyo', 'cos', 'sms', 'ì', 'ì']
# neva
# ['aiyo', 'cos', 'sms', 'ì', 'ì', 'neva']
# reply
# ['aiyo', 'cos', 'sms', 'ì', 'ì', 'neva', 'reply']
# wait
# ['aiyo', 'cos', 'sms', 'ì', 'ì', 'neva', 'reply', 'wait']
# 4
# ['aiyo', 'cos', 'sms', 'ì', 'ì', 'neva', 'reply', 'wait', '4']
# ì
# ['aiyo', 'cos', 'sms', 'ì', 'ì', 'neva', 'reply', 'wait', '4', 'ì']
# reply
# ['aiyo', 'cos', 'sms', 'ì', 'ì', 'neva', 'reply', 'wait', '4', 'ì', 'reply']
# lar
# ['aiyo', 'cos', 'sms', 'ì', 'ì', 'neva', 'reply', 'wait', '4', 'ì', 'reply', 'lar']
# tot
# ['aiyo', 'cos', 'sms', 'ì', 'ì', 'neva', 'reply', 'wait', '4', 'ì', 'reply', 'lar', 'tot']
# ì
# ['aiyo', 'cos', 'sms', 'ì', 'ì', 'neva', 'reply', 'wait', '4', 'ì', 'reply', 'lar', 'tot', 'ì']
# nt
# ['aiyo', 'cos', 'sms', 'ì', 'ì', 'neva', 'reply', 'wait', '4', 'ì', 'reply', 'lar', 'tot', 'ì', 'not']
# finish
# ['aiyo', 'cos', 'sms', 'ì', 'ì', 'neva', 'reply', 'wait', '4', 'ì', 'reply', 'lar', 'tot', 'ì', 'not', 'finish']
# ur
# ['aiyo', 'cos', 'sms', 'ì', 'ì', 'neva', 'reply', 'wait', '4', 'ì', 'reply', 'lar', 'tot', 'ì', 'not', 'finish', 'ur']
# lab
# ['aiyo', 'cos', 'sms', 'ì', 'ì', 'neva', 'reply', 'wait', '4', 'ì', 'reply', 'lar', 'tot', 'ì', 'not', 'finish', 'ur', 'lab']
# wat
# ['aiyo', 'cos', 'sms', 'ì', 'ì', 'neva', 'reply', 'wait', '4', 'ì', 'reply', 'lar', 'tot', 'ì', 'not', 'finish', 'ur', 'lab', 'wat']
# living is very simple.. loving is also simple.. laughing is too simple.. winning is tooo simple.. but, being 'simple' is very difficult...;-) :-)
# living
# ['living']
# simple
# ['living', 'simple']
# loving
# ['living', 'simple', 'loving']
# simple
# ['living', 'simple', 'loving', 'simple']
# laughing
# ['living', 'simple', 'loving', 'simple', 'laughing']
# simple
# ['living', 'simple', 'loving', 'simple', 'laughing', 'simple']
# winning
# ['living', 'simple', 'loving', 'simple', 'laughing', 'simple', 'win']
# tooo
# ['living', 'simple', 'loving', 'simple', 'laughing', 'simple', 'win', 'tooo']
# simple
# ['living', 'simple', 'loving', 'simple', 'laughing', 'simple', 'win', 'tooo', 'simple']
# simple
# ['living', 'simple', 'loving', 'simple', 'laughing', 'simple', 'win', 'tooo', 'simple', 'simple']
# difficult
# ['living', 'simple', 'loving', 'simple', 'laughing', 'simple', 'win', 'tooo', 'simple', 'simple', 'difficult']
# tell me something. thats okay.
# tell
# ['tell']
# s
# ['tell', 's']
# okay
# ['tell', 's', 'okay']
# ok
# ok
# ['ok']
# hmm. shall i bring a bottle of wine to keep us amused? just joking! i'll still bring a bottle. red or white? see you tomorrow
# hmm
# ['hmm']
# shall
# ['hmm', 'shall']
# bring
# ['hmm', 'shall', 'bring']
# bottle
# ['hmm', 'shall', 'bring', 'bottle']
# wine
# ['hmm', 'shall', 'bring', 'bottle', 'wine']
# amused
# ['hmm', 'shall', 'bring', 'bottle', 'wine', 'amused']
# joking
# ['hmm', 'shall', 'bring', 'bottle', 'wine', 'amused', 'joke']
# bring
# ['hmm', 'shall', 'bring', 'bottle', 'wine', 'amused', 'joke', 'bring']
# bottle
# ['hmm', 'shall', 'bring', 'bottle', 'wine', 'amused', 'joke', 'bring', 'bottle']
# red
# ['hmm', 'shall', 'bring', 'bottle', 'wine', 'amused', 'joke', 'bring', 'bottle', 'red']
# white
# ['hmm', 'shall', 'bring', 'bottle', 'wine', 'amused', 'joke', 'bring', 'bottle', 'red', 'white']
# tomorrow
# ...
# hi its in durban are you still on this number
# hi
# ['hi']
# durban
# ['hi', 'durban']
# number
# ['hi', 'durban', 'number']
# ic. there are a lotta childporn cars then.
# ic
# ['ic']
# lotta
# ['ic', 'lotta']
# childporn
# ['ic', 'lotta', 'childporn']
# cars
# ['ic', 'lotta', 'childporn', 'car']
# had your contract mobile 11 mnths? latest motorola, nokia etc. all free! double mins & text on orange tariffs. text yes for callback, no to remove from records.
# contract
# ['contract']
# mobile
# ['contract', 'mobile']
# 11
# ['contract', 'mobile', '11']
# mnths
# ['contract', 'mobile', '11', 'mnth']
# latest
# ['contract', 'mobile', '11', 'mnth', 'late']
# motorola
# ['contract', 'mobile', '11', 'mnth', 'late', 'motorola']
# nokia
# ['contract', 'mobile', '11', 'mnth', 'late', 'motorola', 'nokia']
# etc
# ['contract', 'mobile', '11', 'mnth', 'late', 'motorola', 'nokia', 'etc']
# free
# ['contract', 'mobile', '11', 'mnth', 'late', 'motorola', 'nokia', 'etc', 'free']
# double
# ['contract', 'mobile', '11', 'mnth', 'late', 'motorola', 'nokia', 'etc', 'free', 'double']
# mins
# ['contract', 'mobile', '11', 'mnth', 'late', 'motorola', 'nokia', 'etc', 'free', 'double', 'min']
# text
# ['contract', 'mobile', '11', 'mnth', 'late', 'motorola', 'nokia', 'etc', 'free', 'double', 'min', 'text']
# orange
# ['contract', 'mobile', '11', 'mnth', 'late', 'motorola', 'nokia', 'etc', 'free', 'double', 'min', 'text', 'orange']
# tariffs
# ['contract', 'mobile', '11', 'mnth', 'late', 'motorola', 'nokia', 'etc', 'free', 'double', 'min', 'text', 'orange', 'tariffs']
# text
# ['contract', 'mobile', '11', 'mnth', 'late', 'motorola', 'nokia', 'etc', 'free', 'double', 'min', 'text', 'orange', 'tariffs', 'text']
# yes
# ['contract', 'mobile', '11', 'mnth', 'late', 'motorola', 'nokia', 'etc', 'free', 'double', 'min', 'text', 'orange', 'tariffs', 'text', 'yes']
# callback
# ['contract', 'mobile', '11', 'mnth', 'late', 'motorola', 'nokia', 'etc', 'free', 'double', 'min', 'text', 'orange', 'tariffs', 'text', 'yes', 'callback']
# remove
# ['contract', 'mobile', '11', 'mnth', 'late', 'motorola', 'nokia', 'etc', 'free', 'double', 'min', 'text', 'orange', 'tariffs', 'text', 'yes', 'callback', 'remove']
# records
# ['contract', 'mobile', '11', 'mnth', 'late', 'motorola', 'nokia', 'etc', 'free', 'double', 'min', 'text', 'orange', 'tariffs', 'text', 'yes', 'callback', 'remove', 'record']
# no, i was trying it all weekend ;v
# trying
# ['try']
# weekend
# ['try', 'weekend']
# v
# ['try', 'weekend', 'v']
# you know, wot people wear. t shirts, jumpers, hat, belt, is all we know. we r at cribbs
# know
# ['know']
# wot
# ['know', 'wot']
# people
# ['know', 'wot', 'people']
# wear
# ['know', 'wot', 'people', 'wear']
# t
# ['know', 'wot', 'people', 'wear', 't']
# shirts
# ['know', 'wot', 'people', 'wear', 't', 'shirt']
# jumpers
# ['know', 'wot', 'people', 'wear', 't', 'shirt', 'jumper']
# hat
# ['know', 'wot', 'people', 'wear', 't', 'shirt', 'jumper', 'hat']
# belt
# ['know', 'wot', 'people', 'wear', 't', 'shirt', 'jumper', 'hat', 'belt']
# know
# ['know', 'wot', 'people', 'wear', 't', 'shirt', 'jumper', 'hat', 'belt', 'know']
# r
# ['know', 'wot', 'people', 'wear', 't', 'shirt', 'jumper', 'hat', 'belt', 'know', 'r']
# cribbs
# ['know', 'wot', 'people', 'wear', 't', 'shirt', 'jumper', 'hat', 'belt', 'know', 'r', 'cribb']
# cool, what time you think you can get here?
# cool
# ['cool']
# time
# ['cool', 'time']
# think
# ['cool', 'time', 'think']
# wen did you get so spiritual and deep. that's great
# wen
# ['wen']
# spiritual
# ['wen', 'spiritual']
# deep
# ['wen', 'spiritual', 'deep']
# great
# ['wen', 'spiritual', 'deep', 'great']
# have a safe trip to nigeria. wish you happiness and very soon company to share moments with
# safe
# ['safe']
# trip
# ['safe', 'trip']
# nigeria
# ['safe', 'trip', 'nigeria']
# wish
# ['safe', 'trip', 'nigeria', 'wish']
# happiness
# ['safe', 'trip', 'nigeria', 'wish', 'happiness']
# soon
# ['safe', 'trip', 'nigeria', 'wish', 'happiness', 'soon']
# company
# ['safe', 'trip', 'nigeria', 'wish', 'happiness', 'soon', 'company']
# share
# ['safe', 'trip', 'nigeria', 'wish', 'happiness', 'soon', 'company', 'share']
# moments
# ['safe', 'trip', 'nigeria', 'wish', 'happiness', 'soon', 'company', 'share', 'moment']
# hahaha..use your brain dear
# hahaha
# ['hahaha']
# use
# ['hahaha', 'use']
# brain
# ['hahaha', 'use', 'brain']
# dear
# ['hahaha', 'use', 'brain', 'dear']
# well keep in mind i've only got enough gas for one more round trip barring a sudden influx of cash
# mind
# ['mind']
# got
# ['mind', 'get']
# gas
# ['mind', 'get', 'gas']
# round
# ['mind', 'get', 'gas', 'round']
# trip
# ['mind', 'get', 'gas', 'round', 'trip']
# barring
# ['mind', 'get', 'gas', 'round', 'trip', 'bar']
# sudden
# ['mind', 'get', 'gas', 'round', 'trip', 'bar', 'sudden']
# influx
# ['mind', 'get', 'gas', 'round', 'trip', 'bar', 'sudden', 'influx']
# cash
# ['mind', 'get', 'gas', 'round', 'trip', 'bar', 'sudden', 'influx', 'cash']
# yeh. indians was nice. tho it did kane me off a bit he he. we shud go out 4 a drink sometime soon. mite hav 2 go 2 da works 4 a laugh soon. love pete x x
# yeh
# ['yeh']
# indians
# ['yeh', 'indians']
# nice
# ['yeh', 'indians', 'nice']
# tho
# ['yeh', 'indians', 'nice', 'tho']
# kane
# ['yeh', 'indians', 'nice', 'tho', 'kane']
# bit
# ['yeh', 'indians', 'nice', 'tho', 'kane', 'bit']
# shud
# ['yeh', 'indians', 'nice', 'tho', 'kane', 'bit', 'shud']
# 4
# ['yeh', 'indians', 'nice', 'tho', 'kane', 'bit', 'shud', '4']
# drink
# ['yeh', 'indians', 'nice', 'tho', 'kane', 'bit', 'shud', '4', 'drink']
# soon
# ['yeh', 'indians', 'nice', 'tho', 'kane', 'bit', 'shud', '4', 'drink', 'soon']
# mite
# ['yeh', 'indians', 'nice', 'tho', 'kane', 'bit', 'shud', '4', 'drink', 'soon', 'mite']
# hav
# ['yeh', 'indians', 'nice', 'tho', 'kane', 'bit', 'shud', '4', 'drink', 'soon', 'mite', 'hav']
# 2
# ['yeh', 'indians', 'nice', 'tho', 'kane', 'bit', 'shud', '4', 'drink', 'soon', 'mite', 'hav', '2']
# 2
# ['yeh', 'indians', 'nice', 'tho', 'kane', 'bit', 'shud', '4', 'drink', 'soon', 'mite', 'hav', '2', '2']
# da
# ['yeh', 'indians', 'nice', 'tho', 'kane', 'bit', 'shud', '4', 'drink', 'soon', 'mite', 'hav', '2', '2', 'da']
# works
# ['yeh', 'indians', 'nice', 'tho', 'kane', 'bit', 'shud', '4', 'drink', 'soon', 'mite', 'hav', '2', '2', 'da', 'work']
# 4
# ['yeh', 'indians', 'nice', 'tho', 'kane', 'bit', 'shud', '4', 'drink', 'soon', 'mite', 'hav', '2', '2', 'da', 'work', '4']
# laugh
# ['yeh', 'indians', 'nice', 'tho', 'kane', 'bit', 'shud', '4', 'drink', 'soon', 'mite', 'hav', '2', '2', 'da', 'work', '4', 'laugh']
# soon
# ['yeh', 'indians', 'nice', 'tho', 'kane', 'bit', 'shud', '4', 'drink', 'soon', 'mite', 'hav', '2', '2', 'da', 'work', '4', 'laugh', 'soon']
# love
# ['yeh', 'indians', 'nice', 'tho', 'kane', 'bit', 'shud', '4', 'drink', 'soon', 'mite', 'hav', '2', '2', 'da', 'work', '4', 'laugh', 'soon', 'love']
# pete
# ['yeh', 'indians', 'nice', 'tho', 'kane', 'bit', 'shud', '4', 'drink', 'soon', 'mite', 'hav', '2', '2', 'da', 'work', '4', 'laugh', 'soon', 'love', 'pete']
# x
# ['yeh', 'indians', 'nice', 'tho', 'kane', 'bit', 'shud', '4', 'drink', 'soon', 'mite', 'hav', '2', '2', 'da', 'work', '4', 'laugh', 'soon', 'love', 'pete', 'x']
# x
# ['yeh', 'indians', 'nice', 'tho', 'kane', 'bit', 'shud', '4', 'drink', 'soon', 'mite', 'hav', '2', '2', 'da', 'work', '4', 'laugh', 'soon', 'love', 'pete', 'x', 'x']
# yes i have. so that's why u texted. pshew...missing you so much
# yes
# ['yes']
# u
# ['yes', 'u']
# texted
# ['yes', 'u', 'texte']
# pshew
# ['yes', 'u', 'texte', 'pshew']
# missing
# ['yes', 'u', 'texte', 'pshew', 'miss']
# no. i meant the calculation is the same. that  &lt;#&gt; units at  &lt;#&gt; . this school is really expensive. have you started practicing your accent. because its important. and have you decided if you are doing 4years of dental school or if you'll just do the nmde exam.
# meant
# ['mean']
# calculation
# ['mean', 'calculation']
#
# ['mean', 'calculation', ' ']
# lt;#&gt
# ['mean', 'calculation', ' ', 'lt;#&gt']
# units
# ['mean', 'calculation', ' ', 'lt;#&gt', 'unit']
#
# ['mean', 'calculation', ' ', 'lt;#&gt', 'unit', ' ']
# lt;#&gt
# ['mean', 'calculation', ' ', 'lt;#&gt', 'unit', ' ', 'lt;#&gt']
# school
# ['mean', 'calculation', ' ', 'lt;#&gt', 'unit', ' ', 'lt;#&gt', 'school']
# expensive
# ['mean', 'calculation', ' ', 'lt;#&gt', 'unit', ' ', 'lt;#&gt', 'school', 'expensive']
# started
# ['mean', 'calculation', ' ', 'lt;#&gt', 'unit', ' ', 'lt;#&gt', 'school', 'expensive', 'start']
# practicing
# ['mean', 'calculation', ' ', 'lt;#&gt', 'unit', ' ', 'lt;#&gt', 'school', 'expensive', 'start', 'practice']
# accent
# ['mean', 'calculation', ' ', 'lt;#&gt', 'unit', ' ', 'lt;#&gt', 'school', 'expensive', 'start', 'practice', 'accent']
# important
# ['mean', 'calculation', ' ', 'lt;#&gt', 'unit', ' ', 'lt;#&gt', 'school', 'expensive', 'start', 'practice', 'accent', 'important']
# decided
# ['mean', 'calculation', ' ', 'lt;#&gt', 'unit', ' ', 'lt;#&gt', 'school', 'expensive', 'start', 'practice', 'accent', 'important', 'decide']
# 4years
# ['mean', 'calculation', ' ', 'lt;#&gt', 'unit', ' ', 'lt;#&gt', 'school', 'expensive', 'start', 'practice', 'accent', 'important', 'decide', '4years']
# dental
# ['mean', 'calculation', ' ', 'lt;#&gt', 'unit', ' ', 'lt;#&gt', 'school', 'expensive', 'start', 'practice', 'accent', 'important', 'decide', '4years', 'dental']
# school
# ['mean', 'calculation', ' ', 'lt;#&gt', 'unit', ' ', 'lt;#&gt', 'school', 'expensive', 'start', 'practice', 'accent', 'important', 'decide', '4years', 'dental', 'school']
# nmde
# ['mean', 'calculation', ' ', 'lt;#&gt', 'unit', ' ', 'lt;#&gt', 'school', 'expensive', 'start', 'practice', 'accent', 'important', 'decide', '4years', 'dental', 'school', 'nmde']
# exam
# ['mean', 'calculation', ' ', 'lt;#&gt', 'unit', ' ', 'lt;#&gt', 'school', 'expensive', 'start', 'practice', 'accent', 'important', 'decide', '4years', 'dental', 'school', 'nmde', 'exam']
# sorry, i'll call later
# sorry
# ['sorry']
# later
# ['sorry', 'later']
# if you aren't here in the next  &lt;#&gt;  hours imma flip my shit
#
# [' ']
# lt;#&gt
# [' ', 'lt;#&gt']
#
# [' ', 'lt;#&gt', ' ']
# hours
# [' ', 'lt;#&gt', ' ', 'hour']
# imma
# [' ', 'lt;#&gt', ' ', 'hour', 'imma']
# flip
# [' ', 'lt;#&gt', ' ', 'hour', 'imma', 'flip']
# shit
# [' ', 'lt;#&gt', ' ', 'hour', 'imma', 'flip', 'shit']
# anything lor. juz both of us lor.
# lor
# ['lor']
# juz
# ['lor', 'juz']
# lor
# ['lor', 'juz', 'lor']
# get me out of this dump heap. my mom decided to come to lowes. boring.
# dump
# ['dump']
# heap
# ['dump', 'heap']
# mom
# ['dump', 'heap', 'mom']
# decided
# ['dump', 'heap', 'mom', 'decide']
# come
# ['dump', 'heap', 'mom', 'decide', 'come']
# lowes
# ['dump', 'heap', 'mom', 'decide', 'come', 'lowes']
# boring
# ['dump', 'heap', 'mom', 'decide', 'come', 'lowes', 'boring']
# ok lor... sony ericsson salesman... i ask shuhui then she say quite gd 2 use so i considering...
# ok
# ['ok']
# lor
# ['ok', 'lor']
# sony
# ['ok', 'lor', 'sony']
# ericsson
# ['ok', 'lor', 'sony', 'ericsson']
# salesman
# ['ok', 'lor', 'sony', 'ericsson', 'salesman']
# ask
# ['ok', 'lor', 'sony', 'ericsson', 'salesman', 'ask']
# shuhui
# ['ok', 'lor', 'sony', 'ericsson', 'salesman', 'ask', 'shuhui']
# gd
# ['ok', 'lor', 'sony', 'ericsson', 'salesman', 'ask', 'shuhui', 'gd']
# 2
# ['ok', 'lor', 'sony', 'ericsson', 'salesman', 'ask', 'shuhui', 'gd', '2']
# use
# ['ok', 'lor', 'sony', 'ericsson', 'salesman', 'ask', 'shuhui', 'gd', '2', 'use']
# considering
# ['ok', 'lor', 'sony', 'ericsson', 'salesman', 'ask', 'shuhui', 'gd', '2', 'use', 'consider']
# ard 6 like dat lor.
# ard
# ['ard']
# 6
# ['ard', '6']
# like
# ['ard', '6', 'like']
# dat
# ['ard', '6', 'like', 'dat']
# lor
# ['ard', '6', 'like', 'dat', 'lor']
# why don't you wait 'til at least wednesday to see if you get your .
# wait
# ['wait']
# til
# ['wait', 'til']
# wednesday
# ['wait', 'til', 'wednesday']
# huh y lei...
# huh
# ['huh']
# y
# ['huh', 'y']
# lei
# ['huh', 'y', 'lei']
# reminder from o2: to get 2.50 pounds free call credit and details of great offers pls reply 2 this text with your valid name, house no and postcode
# reminder
# ['reminder']
# o2
# ['reminder', 'o2']
# 2.50
# ['reminder', 'o2', '2.50']
# pounds
# ['reminder', 'o2', '2.50', 'pound']
# free
# ['reminder', 'o2', '2.50', 'pound', 'free']
# credit
# ['reminder', 'o2', '2.50', 'pound', 'free', 'credit']
# details
# ['reminder', 'o2', '2.50', 'pound', 'free', 'credit', 'detail']
# great
# ['reminder', 'o2', '2.50', 'pound', 'free', 'credit', 'detail', 'great']
# offers
# ['reminder', 'o2', '2.50', 'pound', 'free', 'credit', 'detail', 'great', 'offer']
# pls
# ['reminder', 'o2', '2.50', 'pound', 'free', 'credit', 'detail', 'great', 'offer', 'pls']
# reply
# ['reminder', 'o2', '2.50', 'pound', 'free', 'credit', 'detail', 'great', 'offer', 'pls', 'reply']
# 2
# ['reminder', 'o2', '2.50', 'pound', 'free', 'credit', 'detail', 'great', 'offer', 'pls', 'reply', '2']
# text
# ['reminder', 'o2', '2.50', 'pound', 'free', 'credit', 'detail', 'great', 'offer', 'pls', 'reply', '2', 'text']
# valid
# ['reminder', 'o2', '2.50', 'pound', 'free', 'credit', 'detail', 'great', 'offer', 'pls', 'reply', '2', 'text', 'valid']
# house
# ['reminder', 'o2', '2.50', 'pound', 'free', 'credit', 'detail', 'great', 'offer', 'pls', 'reply', '2', 'text', 'valid', 'house']
# postcode
# ['reminder', 'o2', '2.50', 'pound', 'free', 'credit', 'detail', 'great', 'offer', 'pls', 'reply', '2', 'text', 'valid', 'house', 'postcode']
# this is the 2nd time we have tried 2 contact u. u have won the å£750 pound prize. 2 claim is easy, call 087187272008 now1! only 10p per minute. bt-national-rate.
# 2nd
# ['2nd']
# time
# ['2nd', 'time']
# tried
# ['2nd', 'time', 'try']
# 2
# ['2nd', 'time', 'try', '2']
# contact
# ['2nd', 'time', 'try', '2', 'contact']
# u.
# ['2nd', 'time', 'try', '2', 'contact', 'u.']
# u
# ['2nd', 'time', 'try', '2', 'contact', 'u.', 'u']
# won
# ['2nd', 'time', 'try', '2', 'contact', 'u.', 'u', 'win']
# å£750
# ['2nd', 'time', 'try', '2', 'contact', 'u.', 'u', 'win', 'å£750']
# pound
# ['2nd', 'time', 'try', '2', 'contact', 'u.', 'u', 'win', 'å£750', 'pound']
# prize
# ['2nd', 'time', 'try', '2', 'contact', 'u.', 'u', 'win', 'å£750', 'pound', 'prize']
# 2
# ['2nd', 'time', 'try', '2', 'contact', 'u.', 'u', 'win', 'å£750', 'pound', 'prize', '2']
# claim
# ['2nd', 'time', 'try', '2', 'contact', 'u.', 'u', 'win', 'å£750', 'pound', 'prize', '2', 'claim']
# easy
# ['2nd', 'time', 'try', '2', 'contact', 'u.', 'u', 'win', 'å£750', 'pound', 'prize', '2', 'claim', 'easy']
# 087187272008
# ['2nd', 'time', 'try', '2', 'contact', 'u.', 'u', 'win', 'å£750', 'pound', 'prize', '2', 'claim', 'easy', '087187272008']
# now1
# ['2nd', 'time', 'try', '2', 'contact', 'u.', 'u', 'win', 'å£750', 'pound', 'prize', '2', 'claim', 'easy', '087187272008', 'now1']
# 10p
# ['2nd', 'time', 'try', '2', 'contact', 'u.', 'u', 'win', 'å£750', 'pound', 'prize', '2', 'claim', 'easy', '087187272008', 'now1', '10p']
# minute
# ['2nd', 'time', 'try', '2', 'contact', 'u.', 'u', 'win', 'å£750', 'pound', 'prize', '2', 'claim', 'easy', '087187272008', 'now1', '10p', 'minute']
# bt
# ['2nd', 'time', 'try', '2', 'contact', 'u.', 'u', 'win', 'å£750', 'pound', 'prize', '2', 'claim', 'easy', '087187272008', 'now1', '10p', 'minute', 'bt']
# national
# ['2nd', 'time', 'try', '2', 'contact', 'u.', 'u', 'win', 'å£750', 'pound', 'prize', '2', 'claim', 'easy', '087187272008', 'now1', '10p', 'minute', 'bt', 'national']
# rate
# ['2nd', 'time', 'try', '2', 'contact', 'u.', 'u', 'win', 'å£750', 'pound', 'prize', '2', 'claim', 'easy', '087187272008', 'now1', '10p', 'minute', 'bt', 'national', 'rate']
# will ì_ b going to esplanade fr home?
# ì
# ['ì']
# b
# ['ì', 'b']
# going
# ['ì', 'b', 'go']
# esplanade
# ['ì', 'b', 'go', 'esplanade']
# fr
# ['ì', 'b', 'go', 'esplanade', 'fr']
# home
# ['ì', 'b', 'go', 'esplanade', 'fr', 'home']
# pity, * was in mood for that. so...any other suggestions?
# pity
# ['pity']
# mood
# ['pity', 'mood']
# suggestions
# ['pity', 'mood', 'suggestion']
# the guy did some bitching but i acted like i'd be interested in buying something else next week and he gave it to us for free
# guy
# ['guy']
# bitching
# ['guy', 'bitching']
# acted
# ['guy', 'bitching', 'act']
# like
# ['guy', 'bitching', 'act', 'like']
# interested
# ['guy', 'bitching', 'act', 'like', 'interested']
# buying
# ['guy', 'bitching', 'act', 'like', 'interested', 'buy']
# week
# ['guy', 'bitching', 'act', 'like', 'interested', 'buy', 'week']
# gave
# ['guy', 'bitching', 'act', 'like', 'interested', 'buy', 'week', 'give']
# free
# ['guy', 'bitching', 'act', 'like', 'interested', 'buy', 'week', 'give', 'free']
# rofl. its true to its name
# rofl
# ['rofl']
# true
# ['rofl', 'true']

# %%
data.head()
# Out:
#    v1                                                 v2
# 0   0  jurong point crazy available bugis n great wor...
# 1   0                              ok lar joke wif u oni
# 2   1  free entry 2 wkly comp win fa cup final tkts 2...
# 3   0                                u dun early hor u c
# 4   0                              nah think go usf live

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(analyzer='word',stop_words='english')

# %%
text_vector = vectorizer.fit_transform(data['v2'].values.tolist())

# %%
print(text_vector)

# %% [markdown]
# #  - Splitting Data set

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(text_vector.toarray(),data['v1'],test_size=0.2,random_state=20)

# %%
len(x_train)
# Out:
# 4457

# %% [markdown]
# # Model Building

# %%
from sklearn.naive_bayes import BernoulliNB

# %%
modelB = BernoulliNB()
modelB.fit(x_train,y_train)
print(modelB.score(x_train,y_train))
# Out:
# 0.9845187345748261

# %%
y_predictedB = modelB.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(y_test,y_predictedB))
# Out:
# 0.9829596412556054

# %% [markdown]
# ## 98% Accuracy
